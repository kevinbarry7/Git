# %% [markdown]
# TODO: Plotting examples using matplotlib, seaborn, etc.

# %%
from numpy import *
import math
import matplotlib.pyplot as plt

# %% [markdown]
# <h3>Multiple Plots in Same Figure</h3>

# %%
t = linspace(0, 2*math.pi, 400)
a = sin(t)
b = cos(t)
c = a + b

plt.plot(t, a, 'r') # plotting t, a separately 
plt.plot(t, b, 'b') # plotting t, b separately 
plt.plot(t, c, 'g') # plotting t, c separately 
plt.show()

# %%
# alternate method
plt.plot(t, a, t, b, t, c)
plt.show()

# %% [markdown]
# <h3>Plotting in a Loop</h3>

# %%
data = linspace(0, 10, 100)
for i in range(5):
    plt.plot(data, data)
    plt.show()
